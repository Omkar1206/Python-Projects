# %%
# QUIZ GAME - DATA SCIENCE
# Welcome User
print('Welcome to the Data Science Quiz!')

# Ask User Name
user_name = input('Please enter your name: ')

# Greet User
hello_user = 'Hello ' + user_name + '!'
print(hello_user)

score = 0

# Question 1
print('\nQuestion 1: What is the process of converting raw data into a more structured and usable format called?')
user_ans_1 = input('Your answer: ')
if user_ans_1.lower() == 'data preprocessing':
    print('Correct!')
    score += 10
else:
    print('Incorrect! The correct answer is "data preprocessing".')

# Question 2
print('\nQuestion 2: What is the term for a statistical measure of the dispersion or spread of a dataset?')
user_ans_2 = input('Your answer: ')
if user_ans_2.lower() == 'standard deviation':
    print('That\'s right!')
    score += 10
else:
    print('Incorrect! The correct answer is "standard deviation".')

# Question 3
print('\nQuestion 3: What is the technique used to reduce the dimensionality of a dataset while preserving important information?')
user_ans_3 = input('Your answer: ')
if user_ans_3.lower() == 'dimensionality reduction':
    print('Yes!')
    score += 10
else:
    print('Nope! The correct answer is "dimensionality reduction".')

# Question 4
print('\nQuestion 4: What is the process of making predictions based on data called?')
user_ans_4 = input('Your answer: ')
if user_ans_4.lower() == 'machine learning':
    print('Correct!')
    score += 10
else:
    print('Incorrect! The correct answer is "machine learning".')

# Question 5
print('\nQuestion 5: What is the programming language commonly used for data analysis and manipulation in data science?')
user_ans_5 = input('Your answer: ')
if user_ans_5.lower() == 'python':
    print('Right!')
    score += 10
else:
    print('Wrong! The correct answer is "Python".')

# Question 6
print('\nQuestion 6: What is the name of the process used to divide a dataset into a training set and a test set?')
user_ans_6 = input('Your answer: ')
if user_ans_6.lower() == 'train-test split':
    print('Correct!')
    score += 10
else:
    print('Incorrect! The correct answer is "train-test split".')

# Question 7
print('\nQuestion 7: What is the term for a predictive modeling technique where the target variable is categorical?')
user_ans_7 = input('Your answer: ')
if user_ans_7.lower() == 'classification':
    print('Yes!')
    score += 10
else:
    print('Nope! The correct answer is "classification".')

# Question 8
print('\nQuestion 8: What is the name of the process used to find the best parameters for a machine learning model?')
user_ans_8 = input('Your answer: ')
if user_ans_8.lower() == 'hyperparameter tuning':
    print('Correct!')
    score += 10
else:
    print('Incorrect! The correct answer is "hyperparameter tuning".')

# Question 9
print('\nQuestion 9: What is the term for a type of algorithm that learns to perform a task without being explicitly programmed?')
user_ans_9 = input('Your answer: ')
if user_ans_9.lower() == 'artificial intelligence' or user_ans_9.lower() == 'machine learning':
    print('That\'s right!')
    score += 10
else:
    print('Wrong! The correct answer is "machine learning" or "artificial intelligence".')

# Question 10
print('\nQuestion 10: What is the process of finding patterns or insights in data through exploratory analysis called?')
user_ans_10 = input('Your answer: ')
if user_ans_10.lower() == 'data mining':
    print('Correct!')
    score += 10
else:
    print('Incorrect! The correct answer is "data mining".')

# Display Final Score
final_score = 'Your final score is ' + str(score) + '/100'
print(final_score)
# Out:
# Welcome to the Data Science Quiz!
# Please enter your name: omkar
# Hello omkar!
#
# Question 1: What is the process of converting raw data into a more structured and usable format called?
# Your answer: data preprocessing
# Correct!
#
# Question 2: What is the term for a statistical measure of the dispersion or spread of a dataset?
# Your answer: variance
# Incorrect! The correct answer is "standard deviation".
#
# Question 3: What is the technique used to reduce the dimensionality of a dataset while preserving important information?
# Your answer: pca
# Nope! The correct answer is "dimensionality reduction".
#
# Question 4: What is the process of making predictions based on data called?
# Your answer: machine learning
# Correct!
#
# Question 5: What is the programming language commonly used for data analysis and manipulation in data science?
# Your answer: python
# Right!
#
# Question 6: What is the name of the process used to divide a dataset into a training set and a test set?
# ...
